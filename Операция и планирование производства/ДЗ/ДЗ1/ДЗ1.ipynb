# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
s1 = [80, 5]
s2 = [60, 30]
s3 = [45, 45]
s4 = [20, 50]

# %%
variants = np.array([s1, s2, s3, s4], 'int8')
probabilities = np.array([0.6, 0.4])

# %%
variants
# Out:
# array([[80,  5],
#        [60, 30],
#        [45, 45],
#        [20, 50]], dtype=int8)

# %%
excepted_profit = variants[:, 0] * probabilities[0] \
                + variants[:, 1] * probabilities[1]

# %%
plt.figure(1, figsize=(15, 7), dpi=100)
for variant in variants:
    plt.plot([0, 1], variant, color='black', lw=2)
plt.xlim(0, 1)
plt.ylim(0, np.max(variants) + 5)
plt.vlines(0.45, 0, np.max(variants) + 10, colors='grey', linestyles=':')
plt.vlines(0.5, 0, np.max(variants) + 10, colors='grey', linestyles=':')
plt.vlines(0.83, 0, np.max(variants) + 10, colors='grey', linestyles=':')
plt.tick_params(axis='y', which='both', labelleft=True, labelright=True)
plt.savefig('./img/graph.svg', bbox_inches='tight')
plt.show()

# %%
df = pd.DataFrame(
    variants,
    columns=[f'Y{i + 1}' for i in range(len(variants[0, :]))],
    index=[f'S{i + 1}' for i in range(len(variants[:, 0]))]
)

# %%
df['Ожидаемая прибыль'] = excepted_profit.astype('int8')

def highlight_max(s, props=''):
    return np.where(s == np.nanmax(s.values), props, '')
df.style.apply(highlight_max, props='color:white;background-color:red', axis=0)
# df.style.applymap(lambda v: 'color: red;' if max(v) else None)
# Out:
# <style type="text/css">
# #T_86358_row0_col0, #T_86358_row0_col2, #T_86358_row3_col1 {
#   color: white;
#   background-color: red;
# }
# </style>
# <table id="T_86358">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_86358_level0_col0" class="col_heading level0 col0" >Y1</th>
#       <th id="T_86358_level0_col1" class="col_heading level0 col1" >Y2</th>
#       <th id="T_86358_level0_col2" class="col_heading level0 col2" >Ожидаемая прибыль</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_86358_level0_row0" class="row_heading level0 row0" >S1</th>
#       <td id="T_86358_row0_col0" class="data row0 col0" >80</td>
#       <td id="T_86358_row0_col1" class="data row0 col1" >5</td>
#       <td id="T_86358_row0_col2" class="data row0 col2" >50</td>
#     </tr>
#     <tr>
#       <th id="T_86358_level0_row1" class="row_heading level0 row1" >S2</th>
#       <td id="T_86358_row1_col0" class="data row1 col0" >60</td>
#       <td id="T_86358_row1_col1" class="data row1 col1" >30</td>
#       <td id="T_86358_row1_col2" class="data row1 col2" >48</td>
#     </tr>
#     <tr>
#       <th id="T_86358_level0_row2" class="row_heading level0 row2" >S3</th>
#       <td id="T_86358_row2_col0" class="data row2 col0" >45</td>
#       <td id="T_86358_row2_col1" class="data row2 col1" >45</td>
#       <td id="T_86358_row2_col2" class="data row2 col2" >45</td>
#     </tr>
#     <tr>
#       <th id="T_86358_level0_row3" class="row_heading level0 row3" >S4</th>
#       <td id="T_86358_row3_col0" class="data row3 col0" >20</td>
#       <td id="T_86358_row3_col1" class="data row3 col1" >50</td>
#       <td id="T_86358_row3_col2" class="data row3 col2" >32</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Критерий Лапласа

# %%
laplass = np.sum(variants, axis=1) * 0.5
laplass
# Out:
# array([42.5, 45. , 45. , 35. ])

# %%
df2 = pd.DataFrame(
    variants,
    columns=[f'Y{i + 1}' for i in range(len(variants[0, :]))],
    index=[f'S{i + 1}' for i in range(len(variants[:, 0]))]
)
df2['Лапласс'] = laplass
df2
# Out:
#     Y1  Y2  Лапласс
# S1  80   5     42.5
# S2  60  30     45.0
# S3  45  45     45.0
# S4  20  50     35.0

# %% [markdown]
# ## Критерий максимина

# %%
df3 = pd.DataFrame(
    variants,
    columns=[f'Y{i + 1}' for i in range(len(variants[0, :]))],
    index=[f'S{i + 1}' for i in range(len(variants[:, 0]))]
)

df3['Min'] = np.min(variants, axis=1)
df3
# Out:
#     Y1  Y2  Min
# S1  80   5    5
# S2  60  30   30
# S3  45  45   45
# S4  20  50   20

# %%
maximinimum = np.max(df3.Min)
maximinimum
# Out:
# 45

# %% [markdown]
# ## Критерий Сэвидна

# %%
regets = np.array([np.abs(variants[:, i] - np.max(variants[:, i])) for i in range(2)]).T
max_regets = np.max(regets, axis=1)

# %%
df4 = pd.DataFrame(
    variants,
    columns=[f'Y{i + 1}' for i in range(len(variants[0, :]))],
    index=[f'S{i + 1}' for i in range(len(variants[:, 0]))]
)
df4['Отклонения 1'] = regets[:, 0]
df4['Отклонения 2'] = regets[:, 1]
df4['Наихудший вариант'] = np.min(np.max(regets, axis=1))
df4
# Out:
#     Y1  Y2  Отклонения 1  Отклонения 2  Наихудший вариант
# S1  80   5             0            45                 20
# S2  60  30            20            20                 20
# S3  45  45            35             5                 20
# S4  20  50            60             0                 20
